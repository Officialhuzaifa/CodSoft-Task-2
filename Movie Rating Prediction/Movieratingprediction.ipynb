# %% [markdown]
# **TASK-2 : MOVIE RATING PREDICTION**

# %% [markdown]
# *IMPORTING IMPORTANT LIBRARIES*

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# *DOWNLOADING DATASETS*

# %%
df_movie = pd.read_csv('/content/IMDb Movies India.csv', sep="::", engine='python', encoding='latin-1') # Change the encoding to 'latin-1' or another appropriate encoding
df_movie.dropna(inplace=True)
df_movie.head()
# Out:
#   Name,Year,Duration,Genre,Rating,Votes,Director,Actor 1,Actor 2,Actor 3
# 0  ,,,Drama,,,J.S. Randhawa,Manmauji,Birbal,Rajen...
# 1  #Gadhvi (He thought he was Gandhi),(2019),109 ...
# 2  #Homecoming,(2021),90 min,"Drama, Musical",,,S...
# 3  #Yaaram,(2019),110 min,"Comedy, Romance",4.4,3...
# 4  ...And Once Again,(2010),105 min,Drama,,,Amol ...

# %%
df_movie.shape
# Out:
# (15509, 1)

# %%
df_movie.describe()
# Out:
#        Name,Year,Duration,Genre,Rating,Votes,Director,Actor 1,Actor 2,Actor 3
# count                                               15509
# unique                                              15503
# top                   Musafir,,,Thriller,,,Shiva Dagar,,,
# freq                                                    2

# %%
df_movie.isna().sum()
# Out:
# Name,Year,Duration,Genre,Rating,Votes,Director,Actor 1,Actor 2,Actor 3    0
# dtype: int64

# %%
df_movie = pd.read_csv('/content/IMDb Movies India.csv', sep="::", engine='python', encoding='latin-1') # Change the encoding to 'latin-1' or another appropriate encoding
df_movie.dropna(inplace=True)
df_movie.head(10)
# Out:
#   Name,Year,Duration,Genre,Rating,Votes,Director,Actor 1,Actor 2,Actor 3
# 0  ,,,Drama,,,J.S. Randhawa,Manmauji,Birbal,Rajen...
# 1  #Gadhvi (He thought he was Gandhi),(2019),109 ...
# 2  #Homecoming,(2021),90 min,"Drama, Musical",,,S...
# 3  #Yaaram,(2019),110 min,"Comedy, Romance",4.4,3...
# 4  ...And Once Again,(2010),105 min,Drama,,,Amol ...
# 5  ...Aur Pyaar Ho Gaya,(1997),147 min,"Comedy, D...
# 6  ...Yahaan,(2005),142 min,"Drama, Romance, War"...
# 7  .in for Motion,(2008),59 min,Documentary,,,Ani...
# 8  ?: A Question Mark,(2012),82 min,"Horror, Myst...
# 9  @Andheri,(2014),116 min,"Action, Crime, Thrill...

# %% [markdown]
# *DOWNLOADING DATASETS*

# %%
import pandas as pd
df_ratings = pd.read_csv('/content/ratings.csv')
df_ratings.shape
# Out:
# (100836, 4)

# %%
df_ratings.describe()
# Out:
#               userId        movieId         rating     timestamp
# count  100836.000000  100836.000000  100836.000000  1.008360e+05
# mean      326.127564   19435.295718       3.501557  1.205946e+09
# std       182.618491   35530.987199       1.042529  2.162610e+08
# min         1.000000       1.000000       0.500000  8.281246e+08
# 25%       177.000000    1199.000000       3.000000  1.019124e+09
# 50%       325.000000    2991.000000       3.500000  1.186087e+09
# 75%       477.000000    8122.000000       4.000000  1.435994e+09
# max       610.000000  193609.000000       5.000000  1.537799e+09

# %%
df_ratings.isna().sum()
# Out:
# userId       0
# movieId      0
# rating       0
# timestamp    0
# dtype: int64

# %%
df_movie = pd.read_csv('/content/IMDb Movies India.csv', sep="::", engine='python', encoding='latin-1') # Change the encoding to 'latin-1' or another appropriate encoding
df_movie.dropna(inplace=True)
df_movie.head(10)
# Out:
#   Name,Year,Duration,Genre,Rating,Votes,Director,Actor 1,Actor 2,Actor 3
# 0  ,,,Drama,,,J.S. Randhawa,Manmauji,Birbal,Rajen...
# 1  #Gadhvi (He thought he was Gandhi),(2019),109 ...
# 2  #Homecoming,(2021),90 min,"Drama, Musical",,,S...
# 3  #Yaaram,(2019),110 min,"Comedy, Romance",4.4,3...
# 4  ...And Once Again,(2010),105 min,Drama,,,Amol ...
# 5  ...Aur Pyaar Ho Gaya,(1997),147 min,"Comedy, D...
# 6  ...Yahaan,(2005),142 min,"Drama, Romance, War"...
# 7  .in for Motion,(2008),59 min,Documentary,,,Ani...
# 8  ?: A Question Mark,(2012),82 min,"Horror, Myst...
# 9  @Andheri,(2014),116 min,"Action, Crime, Thrill...

# %% [markdown]
# *DOWNLOADING DATASETS*

# %%
import pandas as pd

# Read the CSV file into a pandas DataFrame
user_data = pd.read_csv('/User_Data.csv')

# Now you can call the describe() method on the DataFrame
user_data.describe()
# Out:
#             User ID         Age  EstimatedSalary   Purchased
# count  4.000000e+02  400.000000       400.000000  400.000000
# mean   1.569154e+07   37.655000     69742.500000    0.357500
# std    7.165832e+04   10.482877     34096.960282    0.479864
# min    1.556669e+07   18.000000     15000.000000    0.000000
# 25%    1.562676e+07   29.750000     43000.000000    0.000000
# 50%    1.569434e+07   37.000000     70000.000000    0.000000
# 75%    1.575036e+07   46.000000     88000.000000    1.000000
# max    1.581524e+07   60.000000    150000.000000    1.000000

# %%
from sklearn.preprocessing import LabelEncoder
labelencoder = LabelEncoder()

# Apply Label Encoding to the 'Gender' column in the original DataFrame
user_data['Gender'] = labelencoder.fit_transform(user_data['Gender'])

# Now, you can call describe() to get the statistics, including the encoded 'Gender'
user_data.describe().head()
# Out:
#             User ID      Gender         Age  EstimatedSalary   Purchased
# count  4.000000e+02  400.000000  400.000000       400.000000  400.000000
# mean   1.569154e+07    0.490000   37.655000     69742.500000    0.357500
# std    7.165832e+04    0.500526   10.482877     34096.960282    0.479864
# min    1.556669e+07    0.000000   18.000000     15000.000000    0.000000
# 25%    1.562676e+07    0.000000   29.750000     43000.000000    0.000000

# %%
user_data.isna().sum()
# Out:
# User ID            0
# Gender             0
# Age                0
# EstimatedSalary    0
# Purchased          0
# dtype: int64

# %% [markdown]
# > ***CONCATENATING THE DATASETS***

# %%
df_data=pd.concat([df_movie,df_ratings,user_data],axis=1)
df_data.dropna()
df_data.head(10)
# Out:
#   Name,Year,Duration,Genre,Rating,Votes,Director,Actor 1,Actor 2,Actor 3  \
# 0  ,,,Drama,,,J.S. Randhawa,Manmauji,Birbal,Rajen...
# 1  #Gadhvi (He thought he was Gandhi),(2019),109 ...
# 2  #Homecoming,(2021),90 min,"Drama, Musical",,,S...
# 3  #Yaaram,(2019),110 min,"Comedy, Romance",4.4,3...
# 4  ...And Once Again,(2010),105 min,Drama,,,Amol ...
# 5  ...Aur Pyaar Ho Gaya,(1997),147 min,"Comedy, D...
# 6  ...Yahaan,(2005),142 min,"Drama, Romance, War"...
# 7  .in for Motion,(2008),59 min,Documentary,,,Ani...
# 8  ?: A Question Mark,(2012),82 min,"Horror, Myst...
# 9  @Andheri,(2014),116 min,"Action, Crime, Thrill...
#
#    userId  movieId  rating  timestamp     User ID  Gender   Age  \
# 0       1        1     4.0  964982703  15624510.0     1.0  19.0
# 1       1        3     4.0  964981247  15810944.0     1.0  35.0
# 2       1        6     4.0  964982224  15668575.0     0.0  26.0
# 3       1       47     5.0  964983815  15603246.0     0.0  27.0
# ...

# %%
df_data.shape
# Out:
# (100836, 10)

# %% [markdown]
# ***REMOVING UNNECESSARY COLUMNS***

# %%
df2=df_data.drop(["EstimatedSalary","Purchased","timestamp"],axis=1)
df2.head()
# Out:
#   Name,Year,Duration,Genre,Rating,Votes,Director,Actor 1,Actor 2,Actor 3  \
# 0  ,,,Drama,,,J.S. Randhawa,Manmauji,Birbal,Rajen...
# 1  #Gadhvi (He thought he was Gandhi),(2019),109 ...
# 2  #Homecoming,(2021),90 min,"Drama, Musical",,,S...
# 3  #Yaaram,(2019),110 min,"Comedy, Romance",4.4,3...
# 4  ...And Once Again,(2010),105 min,Drama,,,Amol ...
#
#    userId  movieId  rating     User ID  Gender   Age
# 0       1        1     4.0  15624510.0     1.0  19.0
# 1       1        3     4.0  15810944.0     1.0  35.0
# 2       1        6     4.0  15668575.0     0.0  26.0
# 3       1       47     5.0  15603246.0     0.0  27.0
# 4       1       50     5.0  15804002.0     1.0  19.0

# %%
df2.describe()
# Out:
#               userId        movieId         rating       User ID      Gender  \
# count  100836.000000  100836.000000  100836.000000  4.000000e+02  400.000000
# mean      326.127564   19435.295718       3.501557  1.569154e+07    0.490000
# std       182.618491   35530.987199       1.042529  7.165832e+04    0.500526
# min         1.000000       1.000000       0.500000  1.556669e+07    0.000000
# 25%       177.000000    1199.000000       3.000000  1.562676e+07    0.000000
# 50%       325.000000    2991.000000       3.500000  1.569434e+07    0.000000
# 75%       477.000000    8122.000000       4.000000  1.575036e+07    1.000000
# max       610.000000  193609.000000       5.000000  1.581524e+07    1.000000
#
#               Age
# count  400.000000
# mean    37.655000
# std     10.482877
# min     18.000000
# 25%     29.750000
# 50%     37.000000
# 75%     46.000000
# max     60.000000

# %%
df2.isna().sum()
# Out:
# Name,Year,Duration,Genre,Rating,Votes,Director,Actor 1,Actor 2,Actor 3     85327
# userId                                                                         0
# movieId                                                                        0
# rating                                                                         0
# User ID                                                                   100436
# Gender                                                                    100436
# Age                                                                       100436
# dtype: int64

# %% [markdown]
# ***handling missing values***

# %%
df_final=df2.dropna()

# %%
df_final.shape
# Out:
# (400, 7)

# %% [markdown]
# ***VISULAZING THE PREPROCESSED DATA***

# %%
sns.countplot(x=df_final['Gender'],hue=df_final['rating'])
# Out:
# <Axes: xlabel='Gender', ylabel='count'>

# %%
df_final.Age.plot.hist(bins=25)
plt.ylabel("movieId")
plt.xlabel("rating")
# Out:
# Text(0.5, 0, 'rating')

# %%
df_final['rating'].value_counts().plot(kind='bar')
plt.show()

# %%
df_final["movieId"].plot.hist(bins=25)
plt.xlabel("movieId")
plt.ylabel("rating")
# Out:
# Text(0, 0.5, 'rating')

# %%
df_final['Age'].plot.hist(bins=10)
# plt.xlabel("Ratings")
# plt.ylabel("Age")
# Out:
# <Axes: ylabel='Frequency'>

# %%
sns.countplot(x=df_final['Age'],hue=df_final['rating'])
# Out:
# <Axes: xlabel='Age', ylabel='count'>

# %% [markdown]
# ***FINAL DATASET***

# %%
df_final.head()
# Out:
#   Name,Year,Duration,Genre,Rating,Votes,Director,Actor 1,Actor 2,Actor 3  \
# 0  ,,,Drama,,,J.S. Randhawa,Manmauji,Birbal,Rajen...
# 1  #Gadhvi (He thought he was Gandhi),(2019),109 ...
# 2  #Homecoming,(2021),90 min,"Drama, Musical",,,S...
# 3  #Yaaram,(2019),110 min,"Comedy, Romance",4.4,3...
# 4  ...And Once Again,(2010),105 min,Drama,,,Amol ...
#
#    userId  movieId  rating     User ID  Gender   Age
# 0       1        1     4.0  15624510.0     1.0  19.0
# 1       1        3     4.0  15810944.0     1.0  35.0
# 2       1        6     4.0  15668575.0     0.0  26.0
# 3       1       47     5.0  15603246.0     0.0  27.0
# 4       1       50     5.0  15804002.0     1.0  19.0

# %%
input=df_final.drop(['rating','Gender','movieId'], axis=1)
target=df_final['rating']

# %%
target.head()
# Out:
# 0    4.0
# 1    4.0
# 2    4.0
# 3    5.0
# 4    5.0
# Name: rating, dtype: float64

# %%
input.head()
# Out:
#   Name,Year,Duration,Genre,Rating,Votes,Director,Actor 1,Actor 2,Actor 3  \
# 0  ,,,Drama,,,J.S. Randhawa,Manmauji,Birbal,Rajen...
# 1  #Gadhvi (He thought he was Gandhi),(2019),109 ...
# 2  #Homecoming,(2021),90 min,"Drama, Musical",,,S...
# 3  #Yaaram,(2019),110 min,"Comedy, Romance",4.4,3...
# 4  ...And Once Again,(2010),105 min,Drama,,,Amol ...
#
#    userId     User ID   Age
# 0       1  15624510.0  19.0
# 1       1  15810944.0  35.0
# 2       1  15668575.0  26.0
# 3       1  15603246.0  27.0
# 4       1  15804002.0  19.0

# %%
from sklearn.preprocessing import MinMaxScaler
import pandas as pd

# Assuming 'input' is your DataFrame with non-numeric columns
# Select only numeric columns for scaling
numeric_features = input.select_dtypes(include=['number']).columns
input_numeric = input[numeric_features]

# Now apply MinMaxScaler to the numeric data
scaler = MinMaxScaler()
scaled_data = scaler.fit_transform(input_numeric)

# Create a new DataFrame with scaled numeric features
scaled_df = pd.DataFrame(scaled_data, columns=numeric_features, index=input.index)

# If you need to keep the non-numeric columns, you can concatenate them back
final_df = pd.concat([input.drop(columns=numeric_features), scaled_df], axis=1)

final_df.head()
# Out:
#   Name,Year,Duration,Genre,Rating,Votes,Director,Actor 1,Actor 2,Actor 3  \
# 0  ,,,Drama,,,J.S. Randhawa,Manmauji,Birbal,Rajen...
# 1  #Gadhvi (He thought he was Gandhi),(2019),109 ...
# 2  #Homecoming,(2021),90 min,"Drama, Musical",,,S...
# 3  #Yaaram,(2019),110 min,"Comedy, Romance",4.4,3...
# 4  ...And Once Again,(2010),105 min,Drama,,,Amol ...
#
#    userId   User ID       Age
# 0     0.0  0.232636  0.023810
# 1     0.0  0.982732  0.404762
# 2     0.0  0.409926  0.190476
# 3     0.0  0.147083  0.214286
# 4     0.0  0.954801  0.023810

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test=train_test_split(input,target,test_size=0.3)

# %%
print(Y_train)
# Out:
# 136    5.0
# 278    0.5
# 51     5.0
# 70     5.0
# 249    4.0
#       ...
# 162    5.0
# 391    5.0
# 140    5.0
# 289    5.0
# 235    4.0
# Name: rating, Length: 280, dtype: float64

# %%
print(Y_test)
# Out:
# 220    4.0
# 8      5.0
# 183    4.0
# 181    5.0
# 35     5.0
#       ...
# 168    5.0
# 242    4.5
# 196    5.0
# 65     5.0
# 159    5.0
# Name: rating, Length: 120, dtype: float64

# %%
from sklearn.preprocessing import MinMaxScaler
import pandas as pd
from sklearn.preprocessing import LabelEncoder

# Assuming 'input' is your DataFrame with

# %%
from sklearn.preprocessing import MinMaxScaler
import pandas as pd
from sklearn.preprocessing import LabelEncoder

# Assuming 'input' is your DataFrame with non-numeric columns
# Select only numeric columns for scaling
numeric_features = input.select_dtypes(include=['number']).columns
input_numeric = input[numeric_features]

# Now apply MinMaxScaler to the numeric data
scaler = MinMaxScaler()
scaled_data = scaler.fit_transform(input_numeric)

# Create a new DataFrame with scaled numeric features
scaled_df = pd.DataFrame(scaled_data, columns=numeric_features, index=input.index)

# If you need to keep the non-numeric columns, you can concatenate them back
# First, apply Label Encoding to non-numeric columns
non_numeric_features = input.select_dtypes(exclude=['number']).columns
input_non_numeric = input[non_numeric_features]

# Create a LabelEncoder instance
label_encoder = LabelEncoder()

# Apply Label Encoding to each non-numeric column
for col in non_numeric_features:
    input_non_numeric[col] = label_encoder.fit_transform(input_non_numeric[col])

# Concatenate scaled numeric features and encoded non-numeric features
final_df = pd.concat([input_non_numeric, scaled_df], axis=1)

final_df.head()
# Out:
# <ipython-input-43-4644c36faacd>:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   input_non_numeric[col] = label_encoder.fit_transform(input_non_numeric[col])
#    Name,Year,Duration,Genre,Rating,Votes,Director,Actor 1,Actor 2,Actor 3  \
# 0                                                  5
# 1                                                  1
# 2                                                  2
# 3                                                  3
# 4                                                  6
#
#    userId   User ID       Age
# 0     0.0  0.232636  0.023810
# 1     0.0  0.982732  0.404762
# 2     0.0  0.409926  0.190476
# 3     0.0  0.147083  0.214286
# 4     0.0  0.954801  0.023810

# %%
X_test = np.array(X_test)

# %%
print(X_test)
# Out:
#      Name,Year,Duration,Genre,Rating,Votes,Director,Actor 1,Actor 2,Actor 3  \
# 328                                                328
# 169                                                170
# 173                                                174
# 386                                                386
# 53                                                  53
# ..                                                 ...
# 147                                                148
# 338                                                338
# 348                                                348
# 32                                                  30
# 345                                                345
#
#      userId   User ID       Age
# 328     1.0  0.924018  0.428571
# 169     0.0  0.052674  0.261905
# 173     0.0  0.060210  0.380952
# 386     1.0  0.633526  0.738095
# 53      0.0  0.422319  0.404762
# ..      ...       ...       ...
# 147     0.0  0.734030  0.547619
# ...

# %%
from sklearn.model_selection import train_test_split
# Use final_df instead of input
X_train, X_test, Y_train, Y_test=train_test_split(final_df,target,test_size=0.3)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
# ... (your existing code for data loading and preprocessing) ...

# Use final_df instead of input
X_train, X_test, Y_train, Y_test = train_test_split(final_df, target, test_size=0.3)

# Create and train the Linear Regression model
model = LinearRegression()
model.fit(X_train, Y_train)

# Make predictions
predictions = model.predict(X_test)


# ... (rest of your code) ...

# %%
model.predict(X_test)
# Out:
# array([3.6245098 , 3.48488039, 4.44271414, 4.38429827, 4.05633933,
#        4.16479638, 3.43827547, 4.4920106 , 4.19085517, 4.3696839 ,
#        4.01870033, 4.11404493, 4.56978098, 4.3218016 , 3.76906846,
#        3.80479131, 4.3340406 , 3.30616239, 4.34357011, 4.45985865,
#        4.1222116 , 4.39107343, 3.3148588 , 3.37439515, 3.39488907,
#        4.4347492 , 4.18759721, 3.83451874, 3.46719056, 3.28297978,
#        4.42855817, 3.80389299, 4.22852088, 3.62227442, 3.5135365 ,
#        4.23358339, 4.36980237, 3.48062696, 4.42989557, 4.37938264,
#        3.3282592 , 3.88861629, 4.55625768, 3.80449712, 4.41014533,
#        4.33478943, 4.1213798 , 3.56807989, 4.15397248, 4.28258996,
#        3.55036627, 3.42628535, 3.97002711, 4.23430496, 4.31787739,
#        3.40055336, 4.24309237, 4.23489129, 4.34094797, 3.30130698,
#        4.19933745, 3.34055173, 4.07789572, 3.53521381, 4.49678058,
#        4.20764077, 4.39795661, 3.20087076, 4.17155676, 3.54229766,
# ...

# %%
predictions = model.predict(X_test)

# %%
print(Y_test)
# Out:
# 387    4.0
# 35     5.0
# 374    1.0
# 370    3.0
# 95     3.0
#       ...
# 273    0.5
# 327    4.0
# 232    3.0
# 258    3.5
# 381    1.0
# Name: rating, Length: 120, dtype: float64

# %%
# !cp 'Untitled0.ipynb' 'C:/Users/skhuz/Downloads/TASK2_CODSOFT'
# Out:
# cp: cannot stat 'Untitled0.ipynb': No such file or directory
